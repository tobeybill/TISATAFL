# %%
import pandas as pd
import numpy as np
import yfinance as yf

# %%
firm_data = pd.read_csv('../inputs/Firm_data.csv')
data_desc = pd.read_csv('../data_description/Firm_data_descriptions.csv')

# %%
data_desc['Variable Name'] = data_desc['Variable Name'].str.lower()
data_desc = data_desc[['Variable Name','Description']]
column_names = pd.DataFrame(firm_data.columns)
column_names = column_names.rename(columns = {column_names.columns[0]: 'Variable Name'})
data_definitions = column_names.merge(data_desc, 
                how='left',
                on='Variable Name',
                indicator=False,
                validate='1:1')

# %%
data_definitions
# Out:
#    Variable Name                                        Description
# 0          gvkey                GVKEY -- Global Company Key (GVKEY)
# 1       datadate                                                NaN
# 2          fyear                FYEAR -- Data Year - Fiscal (FYEAR)
# 3         indfmt                                                NaN
# 4         consol                                                NaN
# 5         popsrc                                                NaN
# 6        datafmt                                                NaN
# 7            tic                                Ticker Symbol (TIC)
# 8          cusip                                      CUSIP (CUSIP)
# 9           conm                                Company Name (CONM)
# 10         curcd                                                NaN
# 11           fyr                              Fiscal Year-End (FYR)
# 12           act                ACT -- Current Assets - Total (ACT)
# 13            at                          AT -- Assets - Total (AT)
# 14        bkvlps            BKVLPS -- Book Value Per Share (BKVLPS)
# 15          capx                CAPX -- Capital Expenditures (CAPX)
# 16          ceql     CEQL -- Common Equity Liquidation Value (CEQL)
# 17          csho           CSHO -- Common Shares Outstanding (CSHO)
# 18          dltt              DLTT -- Long-Term Debt - Total (DLTT)
# 19            dt            DT -- Total Debt Including Current (DT)
# 20           dvp      DVP -- Dividends - Preferred/Preference (DVP)
# 21        ebitda        EBITDA -- Earnings Before Interest (EBITDA)
# 22           emp                             EMP -- Employees (EMP)
# 23           lct           LCT -- Current Liabilities - Total (LCT)
# 24            lt                     LT -- Liabilities - Total (LT)
# 25            ni                       NI -- Net Income (Loss) (NI)
# 26         ppegt  PPEGT -- Property, Plant and Equipment - Total...
# 27         pstkl  PSTKL -- Preferred Stock Liquidating Value (PS...
# 28          revt                     REVT -- Revenue - Total (REVT)
# 29           seq          SEQ -- Stockholders' Equity - Total (SEQ)
# 30           teq           TEQ -- Stockholders Equity - Total (TEQ)
# 31           xad                   XAD -- Advertising Expense (XAD)
# 32           xrd      XRD -- Research and Development Expense (XRD)
# 33           cik                                   CIK Number (CIK)
# 34        costat                                                NaN
# 35       dvpsp_f  DVPSP_F -- Dividends per Share - Pay Date - Fi...
# 36        mkvalt   MKVALT -- Market Value - Total - Fiscal (MKVALT)
# 37        prcc_f   PRCC_F -- Price Close - Annual - Fiscal (PRCC_F)
# 38       gsector                   GSECTOR -- GIC Sectors (GSECTOR)
# 39         naics  NAICS -- North American Industry Classificatio...

# %% [markdown]
# ### Investment Opportunities

# %% [markdown]
# **Market-to-book**

# %%
def mtb(tic, year):
    market_value = firm_data.query('tic == @tic & fyear == @year')['mkvalt'].iloc[0]
    book_value = firm_data.query('tic == @tic & fyear == @year')['ceql'].iloc[0]
    value = market_value/book_value
    return value

# %% [markdown]
# **Tobin's Q**

# %% [markdown]
# For Tobin's Q -- is "debt" just liabilities? or just debt? (I included both in the dataset)

# %%
def tobinsQ(tic, year):
    price = firm_data.query('tic == @tic & fyear == @year')['prcc_f'].iloc[0]
    so = firm_data.query('tic == @tic & fyear == @year')['csho'].iloc[0]
    assets = firm_data.query('tic == @tic & fyear == @year')['at'].iloc[0]
    equity = firm_data.query('tic == @tic & fyear == @year')['seq'].iloc[0]
    return ((price * so) + assets - equity) / assets

# %% [markdown]
# **R&D Scaled**

# %%
# def rdScaled(tic, year):
#     rd = firm_data.query('tic == @tic & fyear == @year')['xrd']
#     assets = firm_data.query('tic == @tic & fyear == @year')['at']
#     return rd/assets

# %% [markdown]
# **Advertising Scaled**

# %%
# def advScaled(tic, year):
#     adv = firm_data.query('tic == @tic & fyear == @year')['xad']
#     assets = firm_data.query('tic == @tic & fyear == @year')['at']
#     return adv/assets

# %% [markdown]
# **Liquidity**

# %%
def liquidity(tic, year):
    currA = firm_data.query('tic == @tic & fyear == @year')['act'].iloc[0]
    currL = firm_data.query('tic == @tic & fyear == @year')['lct'].iloc[0]
    assets = firm_data.query('tic == @tic & fyear == @year')['at'].iloc[0]
    return (currA-currL)/assets

# %%
liquidity('AAPL',2012)
# Out:
# 0.10854575608869502

# %% [markdown]
# ### Firm Complexity

# %% [markdown]
# **Sales per Firm per Year**

# %%
sales = firm_data[['tic','fyear','ni']].copy()
sales # In millions per year
# Out:
#        tic  fyear      ni
# 0      AAL   2010  -471.0
# 1      AAL   2011 -1979.0
# 2      AAL   2012 -1876.0
# 3      AAL   2013 -1834.0
# 4      AAL   2014  2882.0
# ...    ...    ...     ...
# 4877  ALLE   2015   153.9
# 4878  ALLE   2016   229.1
# 4879  ALLE   2017   273.3
# 4880  ALLE   2018   434.9
# 4881  ALLE   2019   401.8
#
# [4882 rows x 3 columns]

# %%
# To query:
def netIncome(tic, year):
    return firm_data.query('tic == @tic & fyear == @year')['ni'].iloc[0]

# %%
netIncome('AAL', 2012)
# Out:
# -1876.0

# %% [markdown]
# **Number of Employees per Firm per Year**

# %%
employees = firm_data[['tic','fyear','emp']].copy()
employees # In thousands per year
# Out:
#        tic  fyear     emp
# 0      AAL   2010   78.25
# 1      AAL   2011   80.10
# 2      AAL   2012   77.75
# 3      AAL   2013  110.40
# 4      AAL   2014  113.30
# ...    ...    ...     ...
# 4877  ALLE   2015    9.40
# 4878  ALLE   2016    9.40
# 4879  ALLE   2017   10.00
# 4880  ALLE   2018   11.00
# 4881  ALLE   2019   11.00
#
# [4882 rows x 3 columns]

# %%
# To query:
def numEmployees(tic, year):
    return firm_data.query('tic == @tic & fyear == @year')['emp'].iloc[0]

# %%
numEmployees('AAL', 2012)
# Out:
# 77.75

# %% [markdown]
# **Market Value per Firm per Year**

# %%
mv = firm_data[['tic','fyear','mkvalt']].copy()
mv # In millions per year
# Out:
#        tic  fyear      mkvalt
# 0      AAL   2010   2597.5755
# 1      AAL   2011    117.3438
# 2      AAL   2012    266.5571
# 3      AAL   2013   6591.9923
# 4      AAL   2014  37405.5843
# ...    ...    ...         ...
# 4877  ALLE   2015   6327.7267
# 4878  ALLE   2016   6097.5360
# 4879  ALLE   2017   7563.1327
# 4880  ALLE   2018   7543.5153
# 4881  ALLE   2019  11547.8470
#
# [4882 rows x 3 columns]

# %%
# To query:
def marketValue(tic, year):
    return firm_data.query('tic == @tic & fyear == @year')['mkvalt'].iloc[0]

# %%
marketValue('AAL', 2012)
# Out:
# 266.5571

# %% [markdown]
# ### Monitoring

# %% [markdown]
# **Leverage (Debt / Equity)**

# %%
def dte(tic, year):
    debt = firm_data.query('tic == @tic & fyear == @year')['lt'].iloc[0]
    equity = firm_data.query('tic == @tic & fyear == @year')['seq'].iloc[0]
    return debt/equity

# %% [markdown]
# **Assets in Place**

# %%
def assetsInPlace(tic, year):
    ppe = firm_data.query('tic == @tic & fyear == @year')['ppegt'].iloc[0]
    assets = firm_data.query('tic == @tic & fyear == @year')['at'].iloc[0]
    return ppe/assets

# %% [markdown]
# **CapEx Scaled by Assets**

# %%
def capexAssets(tic, year):
    capx = firm_data.query('tic == @tic & fyear == @year')['capx'].iloc[0]
    assets = firm_data.query('tic == @tic & fyear == @year')['at'].iloc[0]
    return capx/assets

# %%
# All variables but Tobin's Q

firm_date_data = firm_data[['tic','fyear']].copy()
firm_date_data = firm_date_data.dropna()

# %% [markdown]
# **Return on Assets**

# %%
def roa(tic, year):
    ni = firm_data.query('tic == @tic & fyear == @year')['ni'].iloc[0]
    assets = firm_data.query('tic == @tic & fyear == @year')['at'].iloc[0]
    return ni/assets

# %%
firm_date_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4882 entries, 0 to 4881
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tic     4882 non-null   object
#  1   fyear   4882 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 76.4+ KB

# %%
null_mask = firm_date_data.isnull().any(axis=1)
print(firm_date_data[null_mask])
firm_date_data
# Out:
# Empty DataFrame
# Columns: [tic, fyear]
# Index: []
#        tic  fyear
# 0      AAL   2010
# 1      AAL   2011
# 2      AAL   2012
# 3      AAL   2013
# 4      AAL   2014
# ...    ...    ...
# 4877  ALLE   2015
# 4878  ALLE   2016
# 4879  ALLE   2017
# 4880  ALLE   2018
# 4881  ALLE   2019
#
# [4882 rows x 2 columns]

# %%
# commented for runs

# firm_date_data['liquidity'] = firm_date_data.apply(lambda x: liquidity(x['tic'], x['fyear']), axis=1)
# firm_date_data['net_income'] = firm_date_data.apply(lambda x: netIncome(x['tic'], x['fyear']), axis=1)
# firm_date_data['num_employees'] = firm_date_data.apply(lambda x: numEmployees(x['tic'], x['fyear']), axis=1)
# firm_date_data['market_value'] = firm_date_data.apply(lambda x: marketValue(x['tic'], x['fyear']), axis=1)
# firm_date_data['debt_to_equity'] = firm_date_data.apply(lambda x: dte(x['tic'], x['fyear']), axis=1)
# firm_date_data['assets_in_place'] = firm_date_data.apply(lambda x: assetsInPlace(x['tic'], x['fyear']), axis=1)
# firm_date_data['capex_by_assets'] = firm_date_data.apply(lambda x: capexAssets(x['tic'], x['fyear']), axis=1)
# firm_date_data['return_on_equity'] = firm_date_data.apply(lambda x: roa(x['tic'], x['fyear']), axis=1)

# %%
# commented for runs

# corr_measure = firm_date_data[['tic','fyear']]
# corr_measure['market_to_book'] = corr_measure.apply(lambda x: mtb(x['tic'], x['fyear']), axis=1)
# corr_measure['TobinsQ'] = corr_measure.apply(lambda x: tobinsQ(x['tic'], x['fyear']), axis=1)

# %%
# Data is reported on 12/31 for the year in question, so +1 sets it to year start
firm_date_data['fyear'] = firm_date_data['fyear']+1

# %%
firm_date_data.to_csv('../input_data_clean/director_comp_deter.csv', index=False)

# %%
firm_date_data
# Out:
#        tic  fyear
# 0      AAL   2011
# 1      AAL   2012
# 2      AAL   2013
# 3      AAL   2014
# 4      AAL   2015
# ...    ...    ...
# 4877  ALLE   2016
# 4878  ALLE   2017
# 4879  ALLE   2018
# 4880  ALLE   2019
# 4881  ALLE   2020
#
# [4882 rows x 2 columns]

# %% [markdown]
# ### Firm Performance

# %%
firm_data
# Out:
#        gvkey    datadate  fyear indfmt consol popsrc datafmt   tic      cusip  \
# 0       1045  2010-12-31   2010   INDL      C      D     STD   AAL  02376R102
# 1       1045  2011-12-31   2011   INDL      C      D     STD   AAL  02376R102
# 2       1045  2012-12-31   2012   INDL      C      D     STD   AAL  02376R102
# 3       1045  2013-12-31   2013   INDL      C      D     STD   AAL  02376R102
# 4       1045  2014-12-31   2014   INDL      C      D     STD   AAL  02376R102
# ...      ...         ...    ...    ...    ...    ...     ...   ...        ...
# 4877  316056  2015-12-31   2015   INDL      C      D     STD  ALLE  G0176J109
# 4878  316056  2016-12-31   2016   INDL      C      D     STD  ALLE  G0176J109
# 4879  316056  2017-12-31   2017   INDL      C      D     STD  ALLE  G0176J109
# 4880  316056  2018-12-31   2018   INDL      C      D     STD  ALLE  G0176J109
# 4881  316056  2019-12-31   2019   INDL      C      D     STD  ALLE  G0176J109
#
#                              conm  ...     teq    xad   xrd      cik  costat  \
# 0     AMERICAN AIRLINES GROUP INC  ... -3945.0  165.0   NaN     6201       A
# 1     AMERICAN AIRLINES GROUP INC  ... -7111.0  186.0   NaN     6201       A
# 2     AMERICAN AIRLINES GROUP INC  ... -7987.0  153.0   NaN     6201       A
# 3     AMERICAN AIRLINES GROUP INC  ... -2731.0  166.0   NaN     6201       A
# 4     AMERICAN AIRLINES GROUP INC  ...  2021.0  100.0   NaN     6201       A
# ...                           ...  ...     ...    ...   ...      ...     ...
# 4877                 ALLEGION PLC  ...    29.7    NaN  45.2  1579241       A
# 4878                 ALLEGION PLC  ...   116.4    NaN  47.3  1579241       A
# 4879                 ALLEGION PLC  ...   405.5    NaN  48.3  1579241       A
# 4880                 ALLEGION PLC  ...   654.0    NaN  54.4  1579241       A
# 4881                 ALLEGION PLC  ...   760.4    NaN  54.7  1579241       A
#
#       dvpsp_f      mkvalt   prcc_f  gsector   naics
# 0        0.00   2597.5755    7.790       20  481111
# 1        0.00    117.3438    0.350       20  481111
# 2        0.00    266.5571    0.795       20  481111
# 3        0.00   6591.9923   25.250       20  481111
# 4        0.20  37405.5843   53.630       20  481111
# ...       ...         ...      ...      ...     ...
# 4877     0.40   6327.7267   65.920       20  332510
# 4878     0.48   6097.5360   64.000       20  332510
# 4879     0.64   7563.1327   79.560       20  332510
# 4880     0.84   7543.5153   79.710       20  332510
# 4881     1.08  11547.8470  124.540       20  332510
#
# [4882 rows x 40 columns]

# %% [markdown]
# ### Profitability Performance

# %%
def EBITDAMargin(tic, year):
    ebitda = firm_data.query('tic == @tic & fyear == @year')['ebitda'].iloc[0]
    revenue = firm_data.query('tic == @tic & fyear == @year')['revt'].iloc[0]
    return ebitda/revenue

# %%
def niRev(tic, year):
    netIncome = firm_data.query('tic == @tic & fyear == @year')['ni'].iloc[0]
    revenue = firm_data.query('tic == @tic & fyear == @year')['revt'].iloc[0]
    return netIncome/revenue

# %%
def roe(tic, year):
    netIncome = firm_data.query('tic == @tic & fyear == @year')['ni'].iloc[0]
    equity = firm_data.query('tic == @tic & fyear == @year')['seq'].iloc[0]
    return netIncome/equity

# %% [markdown]
# ### Market Value Performance

# %%
def eps(tic, year):
    netIncome = firm_data.query('tic == @tic & fyear == @year')['ni'].iloc[0]
    prefDiv = firm_data.query('tic == @tic & fyear == @year')['dvp'].iloc[0]
    so = firm_data.query('tic == @tic & fyear == @year')['csho'].iloc[0]
    return (netIncome-prefDiv)/so

# %%
# takes a long time

def stockPrice(tic, year):
    start_date = str(int(year)) + "-01-01"
    end_date = str(int(year)) + "-12-31"
    try:
        ticker_data = yf.download(tic, start=start_date, end=end_date, progress=False)
        start_price = ticker_data['Adj Close'][0]
        end_price = ticker_data['Adj Close'][-1]
        change = (end_price/start_price)-1
        return change
    except IndexError:
        return np.nan

# %%
def divYield(tic, year):
    dividend = firm_data.query('tic == @tic & fyear == @year')['dvpsp_f'].iloc[0]
    price = firm_data.query('tic == @tic & fyear == @year')['prcc_f'].iloc[0]
    return dividend/price

# %%
# takes a long time

def volatility(tic, year):
    start_date = str(int(year)) + "-01-01"
    end_date = str(int(year)) + "-12-31"
    try:
        ticker_data = yf.download(tic, start=start_date, end=end_date, progress=False)
        daily_ret = ticker_data['Adj Close'].pct_change()[1:]
        vol = np.sqrt(252)*daily_ret.std()
        return vol
    except IndexError:
        return np.nan

# %%
def mva(tic, year):
    marketVal = firm_data.query('tic == @tic & fyear == @year')['mkvalt'].iloc[0]
    equity = firm_data.query('tic == @tic & fyear == @year')['seq'].iloc[0]
    return marketVal-equity

# %% [markdown]
# ### Growth Performance

# %%
firm_growth_data = pd.read_csv('../Input_data/growth_perf.csv')

# %%
def assetg(tic, year):
    prior_year = year-1
    try: # try in case data not available for prior year or current year
        yrminus1 = firm_growth_data.query('tic == @tic & fyear == @prior_year')['at'].iloc[0]
        yr = firm_growth_data.query('tic == @tic & fyear == @year')['at'].iloc[0]
        return (yr/yrminus1)-1
    except IndexError: # if data not available, return NaN
        return np.nan

# %%
def revenueg(tic, year):
    prior_year = year-1
    try:
        yrminus1 = firm_growth_data.query('tic == @tic & fyear == @prior_year')['revt'].iloc[0]
        yr = firm_growth_data.query('tic == @tic & fyear == @year')['revt'].iloc[0]
        return (yr/yrminus1)-1
    except IndexError:
        return np.nan

# %%
def incomeg(tic, year):
    prior_year = year-1
    try:
        yrminus1 = firm_growth_data.query('tic == @tic & fyear == @prior_year')['ni'].iloc[0]
        yr = firm_growth_data.query('tic == @tic & fyear == @year')['ni'].iloc[0]
        return (yr/yrminus1)-1
    except IndexError:
        return np.nan

# %%
def employeeg(tic, year):
    prior_year = year-1
    try:
        yrminus1 = firm_growth_data.query('tic == @tic & fyear == @prior_year')['emp'].iloc[0]
        yr = firm_growth_data.query('tic == @tic & fyear == @year')['emp'].iloc[0]
        return (yr/yrminus1)-1
    except IndexError:
        return np.nan

# %% [markdown]
# ### Building the dataframe

# %%
firm_performance = firm_data[['tic','fyear']].copy()
firm_performance = firm_performance.dropna()

# %%
# Profitability
# ROA = NI / assets
firm_performance['roa'] = firm_performance.apply(lambda x: roa(x['tic'], x['fyear']), axis=1)
# EBITDA Margin = EBITDA/total revenue
firm_performance['EBITDA_margin'] = firm_performance.apply(lambda x: EBITDAMargin(x['tic'], x['fyear']), axis=1)
# Net income / Revenue
firm_performance['NI_rev'] = firm_performance.apply(lambda x: niRev(x['tic'], x['fyear']), axis=1)
# ROE = Net income / Shareholders equity
firm_performance['roe'] = firm_performance.apply(lambda x: roe(x['tic'], x['fyear']), axis=1)

# Market value
# EPS = (net income - preferred dividends)/ shares outstanding
firm_performance['eps'] = firm_performance.apply(lambda x: eps(x['tic'], x['fyear']), axis=1)
# Changes in stock price - pull from Yahoo Finance
firm_performance['chng_price'] = firm_performance.apply(lambda x: stockPrice(x['tic'], x['fyear']), axis=1)
# Dividend yield = dividends per share / price per share
firm_performance['div_yield'] = firm_performance.apply(lambda x: divYield(x['tic'], x['fyear']), axis=1)
# Volatility = standard deviation multiplied by the square root of the number of periods of time (252 trading days in US)
firm_performance['vol'] = firm_performance.apply(lambda x: volatility(x['tic'], x['fyear']), axis=1)
# MVA = Market Value of Shares - Shareholders equity (https://corporatefinanceinstitute.com/resources/valuation/market-value-added-mva/)
firm_performance['mva'] = firm_performance.apply(lambda x: mva(x['tic'], x['fyear']), axis=1)
# Tobin's Q = (Market Value of common stock + book value of total assets - book value of common equity)/book value total assets (https://funginstitute.berkeley.edu/wp-content/uploads/2013/12/Younge-Marx-2012-Working-Paper-The-Market-Value-of-Knowledge-Protection-Jan-10-2012.pdf)
    # ((PRCC_F * CSHO) + AT – CEQ ) / AT
firm_performance['tobinsQ'] = firm_performance.apply(lambda x: tobinsQ(x['tic'], x['fyear']), axis=1)

# Growth Performance
# Asset growth
firm_performance['asset_g'] = firm_performance.apply(lambda x: assetg(x['tic'], x['fyear']), axis=1)
# Total revenue growth
firm_performance['revenue_g'] = firm_performance.apply(lambda x: revenueg(x['tic'], x['fyear']), axis=1)
# Net income growth
firm_performance['ni_g'] = firm_performance.apply(lambda x: incomeg(x['tic'], x['fyear']), axis=1)
# Employee growth
firm_performance['employee_g'] = firm_performance.apply(lambda x: employeeg(x['tic'], x['fyear']), axis=1)
# Out:
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BRK.B: No timezone found, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - BF.B: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - KHC: Data doesn't exist for startDate = 1230786000, endDate = 1262235600
#
# 1 Failed download:
# - KHC: Data doesn't exist for startDate = 1262322000, endDate = 1293771600
#
# 1 Failed download:
# - KHC: Data doesn't exist for startDate = 1293858000, endDate = 1325307600
#
# 1 Failed download:
# - KHC: Data doesn't exist for startDate = 1325394000, endDate = 1356930000
#
# 1 Failed download:
# - KHC: Data doesn't exist for startDate = 1357016400, endDate = 1388466000
#
# 1 Failed download:
# - KHC: Data doesn't exist for startDate = 1388552400, endDate = 1420002000
#
# 1 Failed download:
# - HLT: Data doesn't exist for startDate = 1262322000, endDate = 1293771600
#
# 1 Failed download:
# - HLT: Data doesn't exist for startDate = 1293858000, endDate = 1325307600
#
# 1 Failed download:
# - HLT: Data doesn't exist for startDate = 1325394000, endDate = 1356930000
#
# 1 Failed download:
# - KMI: Data doesn't exist for startDate = 1262322000, endDate = 1293771600
#
# 1 Failed download:
# - ZTS: Data doesn't exist for startDate = 1262322000, endDate = 1293771600
#
# 1 Failed download:
# - ZTS: Data doesn't exist for startDate = 1293858000, endDate = 1325307600
#
# 1 Failed download:
# - ZTS: Data doesn't exist for startDate = 1325394000, endDate = 1356930000
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1262322000, endDate = 1293771600
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1293858000, endDate = 1325307600
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1325394000, endDate = 1356930000
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1357016400, endDate = 1388466000
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1388552400, endDate = 1420002000
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1420088400, endDate = 1451538000
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1451624400, endDate = 1483160400
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1483246800, endDate = 1514696400
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1514782800, endDate = 1546232400
#
# 1 Failed download:
# - FRC: Data doesn't exist for startDate = 1546318800, endDate = 1577768400
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/h9/dl1xgx0x2jv7mqj5_8snyz600000gs/T/ipykernel_89760/1648507519.py in <module>
#      13 firm_performance['eps'] = firm_performance.apply(lambda x: eps(x['tic'], x['fyear']), axis=1)
#      14 # Changes in stock price - pull from Yahoo Finance
# ---> 15 firm_performance['chng_price'] = firm_performance.apply(lambda x: stockPrice(x['tic'], x['fyear']), axis=1)
#      16 # Dividend yield = dividends per share / price per share
#      17 firm_performance['div_yield'] = firm_performance.apply(lambda x: divYield(x['tic'], x['fyear']), axis=1)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8846             kwargs=kwargs,
#    8847         )
# -> 8848         return op.apply().__finalize__(self, method="apply")
#    8849
#    8850     def applymap(
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#     731             return self.apply_raw()
#     732
# --> 733         return self.apply_standard()
#     734
#     735     def agg(self):
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#     855
#     856     def apply_standard(self):
# --> 857         results, res_index = self.apply_series_generator()
#     858
#     859         # wrap results
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     871             for i, v in enumerate(series_gen):
#     872                 # ignore SettingWithCopy here in case the user mutates
# --> 873                 results[i] = self.f(v)
#     874                 if isinstance(results[i], ABCSeries):
#     875                     # If we have a view on v, we need to make a copy because
#
# /var/folders/h9/dl1xgx0x2jv7mqj5_8snyz600000gs/T/ipykernel_89760/1648507519.py in <lambda>(x)
#      13 firm_performance['eps'] = firm_performance.apply(lambda x: eps(x['tic'], x['fyear']), axis=1)
#      14 # Changes in stock price - pull from Yahoo Finance
# ---> 15 firm_performance['chng_price'] = firm_performance.apply(lambda x: stockPrice(x['tic'], x['fyear']), axis=1)
#      16 # Dividend yield = dividends per share / price per share
#      17 firm_performance['div_yield'] = firm_performance.apply(lambda x: divYield(x['tic'], x['fyear']), axis=1)
#
# /var/folders/h9/dl1xgx0x2jv7mqj5_8snyz600000gs/T/ipykernel_89760/3401300411.py in stockPrice(tic, year)
#       5     end_date = str(int(year)) + "-12-31"
#       6     try:
# ----> 7         ticker_data = yf.download(tic, start=start_date, end=end_date, progress=False)
#       8         start_price = ticker_data['Adj Close'][0]
#       9         end_price = ticker_data['Adj Close'][-1]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/yfinance/multi.py in download(tickers, start, end, actions, threads, ignore_tz, group_by, auto_adjust, back_adjust, repair, keepna, progress, period, show_errors, interval, prepost, proxy, rounding, timeout)
#     159     if len(tickers) == 1:
#     160         ticker = tickers[0]
# --> 161         return shared._DFS[shared._ISINS.get(ticker, ticker)]
#     162
#     163     try:
#
# KeyError: 'APH'

# %%
firm_performance.info()

# %%
firm_performance

# %%
firm_performance.to_csv('../outputs/Firm_Performance.csv', index=False)
