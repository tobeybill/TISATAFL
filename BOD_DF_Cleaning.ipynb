# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
from datetime import datetime as dt

# %%
df = pd.read_csv('input_data_clean/BOD_DF.csv')

# %%
df = df.drop('Unnamed: 0', axis = 1)

# %% [markdown]
# liquidity              5
# net_income             5
# num_employees          5
# market_value           9
# debt_to_equity         0
# assets_in_place        0
# capex_by_assets        5
# return_on_equity       5

# %%
df
# Out:
#        gvkey ticker  total_sec  othcomp  noneq_incent  cash_fees  \
# 0       1045    AAL     47.951    0.951           0.0     47.000
# 1       1045    AAL      0.000    0.000           0.0      0.000
# 2       1045    AAL    418.608   36.108           0.0    102.500
# 3       1045    AAL    286.838   29.338           0.0    117.500
# 4       1045    AAL    317.368   32.368           0.0    135.000
# ...      ...    ...        ...      ...           ...        ...
# 8768  316056   ALLE    290.810   20.754           0.0    200.000
# 8769  316056   ALLE    236.508    0.000           0.0    166.500
# 8770  316056   ALLE     44.511    0.000           0.0     44.511
# 8771  316056   ALLE    240.033    0.000           0.0    140.000
# 8772  316056   ALLE    240.067    0.000           0.0    140.000
#
#       stock_awards  option_awards spcode     cusip  ... size_category  \
# 0            0.000            0.0     SP  02376R10  ...          Tiny
# ...

# %%
df.columns
# Out:
# Index(['gvkey', 'ticker', 'total_sec', 'othcomp', 'noneq_incent', 'cash_fees',
#        'stock_awards', 'option_awards', 'spcode', 'cusip', 'coname', 'year',
#        'total_director_comp', 'total_othcomp', 'total_noneq_incent',
#        'total_cash_fees', 'total_stock_awards', 'total_option_awards',
#        'mkvalt', 'size_category', 'signature_index', 'liquidity', 'net_income',
#        'num_employees', 'market_value', 'debt_to_equity', 'assets_in_place',
#        'capex_by_assets', 'return_on_equity'],
#       dtype='object')

# %%
df.loc[df['liquidity'].isna()]
# Out:
#        gvkey ticker  total_sec  othcomp  noneq_incent  cash_fees  \
# 80      1447    AXP    284.371   34.371           0.0      100.0
# 81      1447    AXP    284.371   34.371           0.0      100.0
# 82      1447    AXP    284.371   34.371           0.0      100.0
# 83      1447    AXP    284.371   34.371           0.0      100.0
# 84      1447    AXP    284.371   34.371           0.0      100.0
# ...      ...    ...        ...      ...           ...        ...
# 8416  177376    DFS    284.990    0.000           0.0      135.0
# 8417  177376    DFS    284.990    0.000           0.0      135.0
# 8418  177376    DFS    284.990    0.000           0.0      135.0
# 8419  177376    DFS    284.990    0.000           0.0      135.0
# 8420  177376    DFS    284.990    0.000           0.0      135.0
#
#       stock_awards  option_awards spcode     cusip  ... size_category  \
# 80          150.00            0.0     SP  02581610  ...           Big
# ...

# %%
df.loc[df['net_income'].isna()]
# Out:
#        gvkey ticker  total_sec  othcomp  noneq_incent  cash_fees  \
# 80      1447    AXP    284.371   34.371           0.0      100.0
# 81      1447    AXP    284.371   34.371           0.0      100.0
# 82      1447    AXP    284.371   34.371           0.0      100.0
# 83      1447    AXP    284.371   34.371           0.0      100.0
# 84      1447    AXP    284.371   34.371           0.0      100.0
# ...      ...    ...        ...      ...           ...        ...
# 8753  260774   CBRE    299.984    0.000           0.0      100.0
# 8754  260774   CBRE    299.984    0.000           0.0      100.0
# 8755  260774   CBRE    299.984    0.000           0.0      100.0
# 8756  260774   CBRE    299.984    0.000           0.0      100.0
# 8757  260774   CBRE    299.984    0.000           0.0      100.0
#
#       stock_awards  option_awards spcode     cusip  ... size_category  \
# 80         150.000            0.0     SP  02581610  ...           Big
# ...

# %%
df[df['ticker','year','liquidity', 'net_income', 'num_employees', 'market_value', 'capex_by_assets', 'return_on_equity']==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('ticker', 'year', 'liquidity', 'net_income', 'num_employees', 'market_value', 'capex_by_assets', 'return_on_equity')
#
# ...
